# %%
import pickle
import sys
from collections import defaultdict
from pathlib import Path

import cv2
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.cluster.hierarchy as sch
import seaborn as sns
from matplotlib.colors import LogNorm
from mpl_toolkits.axes_grid1.inset_locator import mark_inset, zoomed_inset_axes
from skimage import measure, exposure
import skimage.io
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from typing import List
import dask.dataframe as dd
import dask_ml.cluster

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Import path
module_path = str(Path.cwd().parents[0])
if module_path not in sys.path:
    sys.path.append(module_path)

module_path = str(Path.cwd().parents[0] / "src")

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import utils as utils
from config import *

# %%
csv_file = data_meta / "info_combined.csv"

# Read dataframe containing images information
df = pd.read_csv(csv_file)

# %%
# Parameters
min_intensity = 0.3
random_seed = 1

# %% [markdown]
# # Read data

# %%
df_pixels = pd.read_csv(data_meta / 'pixel_intensity.csv')

# %%
df_pixels.head()
# Out:
#    Hoeschst    p-EGFR  Concanavalin A      PCNA   B-actin  Phalloidin  WGA  \
# 0         0  0.041269             0.0  0.109774  0.000000         0.0  0.0
# 1         0  0.000000             0.0  0.043609  0.000000         0.0  0.0
# 2         0  0.000000             0.0  0.000000  0.008220         0.0  0.0
# 3         0  0.016371             0.0  0.019549  0.011009         0.0  0.0
# 4         0  0.000000             0.0  0.192481  0.000000         0.0  0.0
#
#         APC      DKK1  Non-p-B-catenin  ...      EGFR   B-tubin  Cyclin D1  \
# 0  0.003882  0.000000              0.0  ...  0.148699  0.110687   0.051846
# 1  0.007151  0.010676              0.0  ...  0.126394  0.000000   0.003928
# 2  0.110427  0.000000              0.0  ...  0.223048  0.000000   0.071485
# 3  0.121868  0.000000              0.0  ...  0.275093  0.000000   0.120974
# 4  0.018796  0.016370              0.0  ...  0.252788  0.168893   0.000000
#
#    H3k27me3-488  H3k4me3-647  H3k9Ac-555  Location   X     Y  Id
# 0      0.000000     0.000000    0.105570        10  18  1086   6
# 1      0.002201     0.047569    0.123705        10  19  1086   6
# 2      0.000000     0.072138    0.061528        10  19  1087   6
# 3      0.000000     0.029273    0.029145        10  19  1088   6
# 4      0.000000     0.046001    0.135363        10  20  1085   6
#
# [5 rows x 31 columns]

# %%
pixels = df_pixels.iloc[:, :-4]
pixels = pixels.drop(columns=['Concanavalin A', 'Phalloidin', 'Hoeschst', 'WGA', 'B-actin', 'PCNA'])

pixels.head()
# Out:
#      p-EGFR       APC      DKK1  Non-p-B-catenin  Cyclin E   EMMPRIN  Wnt1  \
# 0  0.041269  0.003882  0.000000              0.0  0.011399  0.000000   0.0
# 1  0.000000  0.007151  0.010676              0.0  0.020605  0.000000   0.0
# 2  0.000000  0.110427  0.000000              0.0  0.000000  0.000000   0.0
# 3  0.016371  0.121868  0.000000              0.0  0.011399  0.021042   0.0
# 4  0.000000  0.018796  0.016370              0.0  0.000000  0.000000   0.0
#
#      RNF 43     p-AKT  p-B-catenin  ...      mTOR    p-mTOR     AXIN1  \
# 0  0.037787  0.035695     0.079777  ...  0.000000  0.000000  0.048759
# 1  0.000000  0.000000     0.047310  ...  0.002365  0.000000  0.143666
# 2  0.048583  0.000000     0.114100  ...  0.081595  0.102069  0.000000
# 3  0.145749  0.000000     0.020408  ...  0.060310  0.213967  0.000000
# 4  0.107962  0.000000     0.000928  ...  0.043754  0.043096  0.106661
#
#        DKK2      EGFR   B-tubin  Cyclin D1  H3k27me3-488  H3k4me3-647  \
# 0  0.000000  0.148699  0.110687   0.051846      0.000000     0.000000
# 1  0.007874  0.126394  0.000000   0.003928      0.002201     0.047569
# 2  0.124672  0.223048  0.000000   0.071485      0.000000     0.072138
# 3  0.040682  0.275093  0.000000   0.120974      0.000000     0.029273
# 4  0.041995  0.252788  0.168893   0.000000      0.000000     0.046001
#
#    H3k9Ac-555
# 0    0.105570
# 1    0.123705
# 2    0.061528
# 3    0.029145
# 4    0.135363
#
# [5 rows x 21 columns]

# %%
# Scale data
# scaler = MinMaxScaler()
# x_scaled = scaler.fit_transform(pixels)
# pixels_scaled = pd.DataFrame(x_scaled, columns=pixels.columns)
pixels_scaled = pixels

# %%
pixel_dark = pixels_scaled.le(min_intensity).all(axis=1)
display(pixel_dark.value_counts())
pixels_bright = pixels_scaled[~pixel_dark]
display(pixels_bright.head())
# Out:
# False    52981896
# True     22842961
# dtype: int64
#       p-EGFR       APC      DKK1  Non-p-B-catenin  Cyclin E   EMMPRIN  \
# 7   0.000000  0.662358  0.012811         0.000000  0.000000  0.000000
# 8   0.068213  0.398191  0.027758         0.000000  0.000000  0.000000
# 13  0.011255  0.358862  0.061922         0.001361  0.000000  0.006554
# 24  0.000341  0.025640  0.058363         0.000000  0.079351  0.000000
# 26  0.000000  0.000000  0.017082         0.000000  0.022359  0.000000
#
#         Wnt1    RNF 43     p-AKT  p-B-catenin  ...      mTOR    p-mTOR  \
# 7   0.000000  0.059379  0.000000     0.139147  ...  0.086326  0.008317
# 8   0.000000  0.021592  0.020319     0.080705  ...  0.000000  0.046876
# 13  0.000000  0.000000  0.019769     0.000000  ...  0.000000  0.063510
# 24  0.064846  0.026991  0.000000     0.000000  ...  0.000000  0.000000
# 26  0.070697  0.067476  0.000000     0.207792  ...  0.020103  0.149701
#
#        AXIN1      DKK2      EGFR   B-tubin  Cyclin D1  H3k27me3-488  \
# 7   0.032216  0.005249  0.042751  0.081107   0.034564      0.000000
# 8   0.067915  0.139108  0.223048  0.043893   0.000786      0.000000
# 13  0.000000  0.167979  0.198885  0.056298   0.000000      0.000367
# 24  0.000000  0.140420  0.042751  0.064885   0.000000      0.000000
# 26  0.030475  0.015748  0.092937  0.000000   0.382561      0.000000
#
#     H3k4me3-647  H3k9Ac-555
# 7      0.010455    0.026554
# 8      0.000000    0.000000
# 13     0.032410    0.044689
# 24     0.039728    0.020725
# 26     0.000000    0.027202
#
# [5 rows x 21 columns]

# %%
X = dd.from_pandas(pixels_bright, chunksize=100000)

# %%
X = X.persist()
X
# Out:
# Dask DataFrame Structure:
#                   p-EGFR      APC     DKK1 Non-p-B-catenin Cyclin E  EMMPRIN     Wnt1   RNF 43    p-AKT p-B-catenin      AKT     mTOR   p-mTOR    AXIN1     DKK2     EGFR  B-tubin Cyclin D1 H3k27me3-488 H3k4me3-647 H3k9Ac-555
# npartitions=530
# 7                float64  float64  float64         float64  float64  float64  float64  float64  float64     float64  float64  float64  float64  float64  float64  float64  float64   float64      float64     float64    float64
# 125608               ...      ...      ...             ...      ...      ...      ...      ...      ...         ...      ...      ...      ...      ...      ...      ...      ...       ...          ...         ...        ...
# ...                  ...      ...      ...             ...      ...      ...      ...      ...      ...         ...      ...      ...      ...      ...      ...      ...      ...       ...          ...         ...        ...
# 75670971             ...      ...      ...             ...      ...      ...      ...      ...      ...         ...      ...      ...      ...      ...      ...      ...      ...       ...          ...         ...        ...
# 75824855             ...      ...      ...             ...      ...      ...      ...      ...      ...         ...      ...      ...      ...      ...      ...      ...      ...       ...          ...         ...        ...
# Dask Name: from_pandas, 530 tasks

# %%
km = dask_ml.cluster.KMeans(n_clusters=60, oversampling_factor=10)
km.fit(X)
# Out:
# KMeans(n_clusters=60, oversampling_factor=10)

# %%
labels = km.labels_

# %%
labels = labels.compute()

# %%
len(labels)
# Out:
# 52981896

# %%
len(X)
# Out:
# 52981896

# %%
with open(data_meta / f"kmeans_labels_new.pickle", "wb") as f:
    pickle.dump([labels, pixels_bright], f)
